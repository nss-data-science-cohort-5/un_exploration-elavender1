# %% [markdown]
# # 3,4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 5

# %%
gdp_df = pd.read_csv("../data/gdp_per_capita.csv")

# %%
gdp_df
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# ...

# %%
gdp_df.head(10)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN
# 6     Afghanistan  2013  2116.465454              NaN
# 7     Afghanistan  2012  2075.491747              NaN
# 8     Afghanistan  2011  1904.559799              NaN
# 9     Afghanistan  2010  1957.029338              NaN

# %%
gdp_df.tail(5)
# Out:
#      Country or Area                                      Year        Value  \
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 6865              NaN
# 6866              NaN
# 6867              NaN
# 6868              NaN
# 6869              NaN

# %%
gdp_df = pd.read_csv("C:/Users/bng19/Documents/nss_projects/un_exploration-elavender1/data/gdp_per_capita.csv", nrows = 6868)

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2019  2065.036398              NaN
# 1        Afghanistan  2018  2033.779002              NaN
# 2        Afghanistan  2017  2058.383832              NaN
# 3        Afghanistan  2016  2057.062164              NaN
# 4        Afghanistan  2015  2068.265904              NaN
# ...              ...   ...          ...              ...
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN
#
# [6868 rows x 4 columns]

# %% [markdown]
# # 6

# %%
gdp_df = gdp_df.drop("Value Footnotes", axis = 1)

# %%
gdp_df.rename(columns = {"Country or Area": "Country", "Year": "Year", "Value": "GDP_Per_Capita"}, inplace = True)

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %% [markdown]
# # 7

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6868 entries, 0 to 6867
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6868 non-null   object
#  1   Year            6868 non-null   int64
#  2   GDP_Per_Capita  6868 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 134.2+ KB

# %%
gdp_df.shape
# Out:
# (6868, 3)

# %% [markdown]
# # The dataset contains 6868 rows and 3 columns. The column country is an object. The column Year is an integer, and the column GDP_Per_Capita is a float.

# %% [markdown]
# # 8

# %%
gdp_df.sort_values("Year", ascending = False)
# Out:
#                               Country  Year  GDP_Per_Capita
# 0                         Afghanistan  2019     2065.036398
# 6752               West Bank and Gaza  2019     6219.960291
# 2171                          Germany  2019    53810.565452
# 256                         Australia  2019    49609.044033
# 5734                        Sri Lanka  2019    13078.098115
# ...                               ...   ...             ...
# 1753                      El Salvador  1990     5264.664725
# 1783                Equatorial Guinea  1990     1039.985049
# 5943  Sub-Saharan Africa (IDA & IBRD)  1990     2838.374656
# 1840                         Eswatini  1990     5097.842205
# 6867                         Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
gdp_df.groupby("Year").count()
# Out:
#       Country  GDP_Per_Capita
# Year
# 1990      207             207
# 1991      208             208
# 1992      209             209
# 1993      212             212
# 1994      214             214
# 1995      221             221
# 1996      221             221
# 1997      223             223
# 1998      223             223
# 1999      224             224
# 2000      231             231
# 2001      232             232
# 2002      233             233
# 2003      233             233
# 2004      234             234
# 2005      234             234
# 2006      235             235
# 2007      235             235
# 2008      235             235
# 2009      236             236
# 2010      236             236
# 2011      237             237
# 2012      237             237
# 2013      238             238
# 2014      238             238
# 2015      238             238
# 2016      238             238
# 2017      238             238
# 2018      237             237
# 2019      231             231

# %% [markdown]
# #8 The data ranges from the years 1990 to 2019. There is a trend of increasing observations per year.  In 1990, the dataset only contained 207 observations.  In 2019, it contained 231.

# %% [markdown]
# # 9

# %%
country_sort = gdp_df.groupby("Country").count()

# %%
country_sort
# Out:
#                      Year  GDP_Per_Capita
# Country
# Afghanistan            18              18
# Albania                30              30
# Algeria                30              30
# Angola                 30              30
# Antigua and Barbuda    30              30
# ...                   ...             ...
# Vietnam                30              30
# West Bank and Gaza     26              26
# World                  30              30
# Zambia                 30              30
# Zimbabwe               30              30
#
# [238 rows x 2 columns]

# %%
country_sort.sort_values("Year", ascending = True)
# Out:
#                            Year  GDP_Per_Capita
# Country
# Djibouti                      7               7
# Turks and Caicos Islands      9               9
# Sint Maarten (Dutch part)    10              10
# Cayman Islands               13              13
# Nauru                        16              16
# ...                         ...             ...
# Honduras                     30              30
# Hong Kong SAR, China         30              30
# IBRD only                    30              30
# Greece                       30              30
# Zimbabwe                     30              30
#
# [238 rows x 2 columns]

# %% [markdown]
# #9 238 countries are represented in the dataset.  Djibouti, Turks and Caicos Islands, Sint Maarten (Dutch part) Cayman Islands and Nauru are least represented. Without knowing the methods in which the data was collected, one could only speculate why some countries are less represented than others.

# %% [markdown]
# # 10

# %%
gdp_2014 = gdp_df[gdp_df["Year"] == 2014]

# %%
gdp_2014
# Out:
#                   Country  Year  GDP_Per_Capita
# 5             Afghanistan  2014     2102.385234
# 23                Albania  2014    11623.866679
# 53                Algeria  2014    11512.705405
# 83                 Angola  2014     8239.828837
# 113   Antigua and Barbuda  2014    18104.241470
# ...                   ...   ...             ...
# 6727              Vietnam  2014     6098.489609
# 6757   West Bank and Gaza  2014     5967.073437
# 6783                World  2014    15189.648507
# 6813               Zambia  2014     3450.046561
# 6843             Zimbabwe  2014     2955.240287
#
# [238 rows x 3 columns]

# %% [markdown]
# # 11

# %%
gdp_2014.describe()
# Out:
#          Year  GDP_Per_Capita
# count   238.0      238.000000
# mean   2014.0    19766.710348
# std       0.0    20983.869623
# min    2014.0      822.610458
# 25%    2014.0     4753.110934
# 50%    2014.0    12209.385755
# 75%    2014.0    26803.610474
# max    2014.0   156514.133850

# %% [markdown]
# # 12

# %%
gdp_per_capita_2014 = gdp_2014[["GDP_Per_Capita"]]

# %%
plt.hist(gdp_per_capita_2014, bins = 15)
# Out:
# (array([105.,  57.,  25.,  17.,  17.,   9.,   3.,   1.,   1.,   1.,   1.,
#           0.,   0.,   0.,   1.]),
#  array([   822.61045782,  11202.04535061,  21581.48024341,  31960.91513621,
#          42340.35002901,  52719.78492181,  63099.2198146 ,  73478.6547074 ,
#          83858.0896002 ,  94237.524493  , 104616.95938579, 114996.39427859,
#         125375.82917139, 135755.26406419, 146134.69895699, 156514.13384978]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# #12 the distribution is skewed to the left with a few outliers on the far right.

# %% [markdown]
# # 13

# %%
gdp_2014.sort_values("GDP_Per_Capita", ascending = True)
# Out:
#                        Country  Year  GDP_Per_Capita
# 1047  Central African Republic  2014      822.610458
# 827                    Burundi  2014      886.235777
# 3781                    Malawi  2014     1027.208496
# 1422           Dem. Rep. Congo  2014     1029.790785
# 4528                     Niger  2014     1127.615541
# ...                        ...   ...             ...
# 561                    Bermuda  2014    77361.104881
# 5464                 Singapore  2014    87808.663157
# 5138                     Qatar  2014    95578.416973
# 3691                Luxembourg  2014   108760.916030
# 3721          Macao SAR, China  2014   156514.133850
#
# [238 rows x 3 columns]

# %%
gdp_2014.sort_values("GDP_Per_Capita", ascending = False)
# Out:
#                        Country  Year  GDP_Per_Capita
# 3721          Macao SAR, China  2014   156514.133850
# 3691                Luxembourg  2014   108760.916030
# 5138                     Qatar  2014    95578.416973
# 5464                 Singapore  2014    87808.663157
# 561                    Bermuda  2014    77361.104881
# ...                        ...   ...             ...
# 4528                     Niger  2014     1127.615541
# 1422           Dem. Rep. Congo  2014     1029.790785
# 3781                    Malawi  2014     1027.208496
# 827                    Burundi  2014      886.235777
# 1047  Central African Republic  2014      822.610458
#
# [238 rows x 3 columns]

# %% [markdown]
# #13 1) Macao SAR, China, 2) Luxembourg, 3) Qatar, 4) Singapore, 5) Bermuda are the top 5 countries.
#
# 1) Central African Republic, 2) Burundi, 3) Malawi, 4) Dem. Rep. Congo 5) Niger are the bottom 5 countries

# %% [markdown]
# # 14

# %%
gdp_df.set_index("Year")
# Out:
#           Country  GDP_Per_Capita
# Year
# 2019  Afghanistan     2065.036398
# 2018  Afghanistan     2033.779002
# 2017  Afghanistan     2058.383832
# 2016  Afghanistan     2057.062164
# 2015  Afghanistan     2068.265904
# ...           ...             ...
# 1994     Zimbabwe     3263.934978
# 1993     Zimbabwe     3033.504852
# 1992     Zimbabwe     3054.889178
# 1991     Zimbabwe     3426.598094
# 1990     Zimbabwe     3324.348171
#
# [6868 rows x 2 columns]

# %%
year = [1990, 2017, "GDP_Per_Capita" ]
gdp_pivoted = gdp_df[gdp_df["Year"].isin(year)]

# %%
gdp_pivoted = gdp_pivoted.pivot_table(values = "GDP_Per_Capita", index = "Country", columns = "Year").dropna()

# %%
gdp_pivoted
# Out:
# Year                         1990          2017
# Country
# Albania               4842.734635  12811.759436
# Algeria               8746.352901  11737.409353
# Angola                5783.429064   7310.901738
# Antigua and Barbuda  15459.551675  19840.076123
# Arab World            9694.667544  14555.474921
# ...                           ...           ...
# Vanuatu               2888.309393   3116.645194
# Vietnam               1673.249634   7155.745829
# World                 9680.269697  16253.385518
# Zambia                2190.182814   3485.005238
# Zimbabwe              3324.348171   3028.245976
#
# [207 rows x 2 columns]

# %% [markdown]
# # 15

# %%
gdp_pivoted = gdp_pivoted.assign(Percent_Change = 100 * (gdp_pivoted[2017] - gdp_pivoted[1990]) / gdp_pivoted[1990])

# %%
gdp_pivoted
# Out:
# Year                         1990          2017  Percent_Change
# Country
# Albania               4842.734635  12811.759436      164.556297
# Algeria               8746.352901  11737.409353       34.197756
# Angola                5783.429064   7310.901738       26.411194
# Antigua and Barbuda  15459.551675  19840.076123       28.335391
# Arab World            9694.667544  14555.474921       50.138980
# ...                           ...           ...             ...
# Vanuatu               2888.309393   3116.645194        7.905517
# Vietnam               1673.249634   7155.745829      327.655604
# World                 9680.269697  16253.385518       67.902197
# Zambia                2190.182814   3485.005238       59.119377
# Zimbabwe              3324.348171   3028.245976       -8.907075
#
# [207 rows x 3 columns]

# %% [markdown]
# 16

# %%
gdp_pivoted[gdp_pivoted["Percent_Change"] < 0].count()
# Out:
# Year
# 1990              17
# 2017              17
# Percent_Change    17
# dtype: int64

# %% [markdown]
# There are 17 countries with negative GDP growth between 1990 and 2017

# %% [markdown]
# # 17

# %%
gdp_pivoted["Percent_Change"].sort_values(ascending = False)
# Out:
# Country
# Equatorial Guinea                              2068.404561
# China                                           907.406281
# Myanmar                                         664.939443
# East Asia & Pacific (excluding high income)     497.560254
# East Asia & Pacific (IDA & IBRD)                497.334945
#                                                   ...
# Central African Republic                        -24.039332
# Ukraine                                         -24.636028
# Burundi                                         -34.710993
# United Arab Emirates                            -39.720953
# Dem. Rep. Congo                                 -41.759785
# Name: Percent_Change, Length: 207, dtype: float64

# %%
gdp_df.reset_index
df_eg = gdp_df.set_index('Country').loc[['Equatorial Guinea']]
df_eg
# Out:
#                    Year  GDP_Per_Capita
# Country
# Equatorial Guinea  2019    18558.003852
# Equatorial Guinea  2018    20359.845144
# Equatorial Guinea  2017    22551.083246
# Equatorial Guinea  2016    24827.072978
# Equatorial Guinea  2015    28313.602763
# Equatorial Guinea  2014    32436.466793
# Equatorial Guinea  2013    33678.706547
# Equatorial Guinea  2012    36671.357436
# Equatorial Guinea  2011    35378.023284
# Equatorial Guinea  2010    34732.255956
# Equatorial Guinea  2009    39913.732604
# Equatorial Guinea  2008    41249.438662
# Equatorial Guinea  2007    36685.298706
# Equatorial Guinea  2006    33330.805598
# Equatorial Guinea  2005    32389.861726
# Equatorial Guinea  2004    29004.186721
# Equatorial Guinea  2003    21944.697412
# Equatorial Guinea  2002    20084.465030
# Equatorial Guinea  2001    17523.434190
# Equatorial Guinea  2000    11176.500522
# Equatorial Guinea  1999     9851.190917
# Equatorial Guinea  1998     8166.052518
# ...

# %%
plt.plot(df_eg["Year"], df_eg["GDP_Per_Capita"], color= "red")
plt.title("Equatorial Guinea")
plt.show()

# %%
df_china = gdp_df.set_index('Country').loc[['China']]
df_china
# Out:
#          Year  GDP_Per_Capita
# Country
# China    2019    16092.300767
# China    2018    15242.985858
# China    2017    14344.421239
# China    2016    13487.822482
# China    2015    12691.821553
# China    2014    11917.338496
# China    2013    11149.867559
# China    2012    10397.561415
# China    2011     9686.615290
# China    2010     8884.588031
# China    2009     8069.354638
# China    2008     7412.874363
# China    2007     6795.174012
# China    2006     5979.781712
# China    2005     5334.646639
# China    2004     4817.211845
# China    2003     4400.825183
# China    2002     4024.355697
# China    2001     3712.338132
# China    2000     3451.679231
# China    1999     3206.730026
# China    1998     3004.427342
# China    1997     2812.711135
# China    1996     2601.363426
# China    1995     2391.477116
# China    1994     2178.924057
# China    1993     1949.534268
# China    1992     1731.657215
# China    1991     1534.705272
# ...

# %%
plt.plot(df_china["Year"], df_china["GDP_Per_Capita"], color= "red")
plt.title("China")
plt.show()

# %% [markdown]
# # 18

# %%
continents_df = pd.read_csv("../data/continents.csv")
continents_df
# Out:
#     Continent             Country
# 0        Asia         Afghanistan
# 1      Europe             Albania
# 2      Africa             Algeria
# 3      Europe             Andorra
# 4      Africa              Angola
# ..        ...                 ...
# 211      Asia             Vietnam
# 212      Asia  West Bank and Gaza
# 213      Asia               Yemen
# 214    Africa              Zambia
# 215    Africa            Zimbabwe
#
# [216 rows x 2 columns]

# %% [markdown]
# # 19

# %%
gdp_df = pd.merge(continents_df, gdp_df, on = "Country")
gdp_df = gdp_df.dropna()
gdp_df
# Out:
#      Continent      Country  Year  GDP_Per_Capita
# 0         Asia  Afghanistan  2019     2065.036398
# 1         Asia  Afghanistan  2018     2033.779002
# 2         Asia  Afghanistan  2017     2058.383832
# 3         Asia  Afghanistan  2016     2057.062164
# 4         Asia  Afghanistan  2015     2068.265904
# ...        ...          ...   ...             ...
# 5438    Africa     Zimbabwe  1994     3263.934978
# 5439    Africa     Zimbabwe  1993     3033.504852
# 5440    Africa     Zimbabwe  1992     3054.889178
# 5441    Africa     Zimbabwe  1991     3426.598094
# 5442    Africa     Zimbabwe  1990     3324.348171
#
# [5443 rows x 4 columns]

# %% [markdown]
# # 20

# %%
bar_chart = gdp_df[["Continent", "Country"]]
bar_chart = bar_chart.drop_duplicates()
df_country_count = bar_chart.groupby(['Continent']).count()
df_country_count = df_country_count["Country"]
df_continent_count = gdp_df["Continent"].drop_duplicates()
plt.bar(df_continent_count, df_country_count)
plt.show()

# %% [markdown]
# # 21

# %%
gdp_df_2014 = gdp_df[gdp_df["Year"] == 2014]
sns.boxplot(x=gdp_df["Continent"], y=gdp_df["GDP_Per_Capita"])
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='GDP_Per_Capita'>

# %% [markdown]
# # 22

# %%
internet_df = pd.read_csv("../data/internet_use.csv.csv", nrows= 4495)
internet_df
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 0        Afghanistan  2014  6.390000              NaN
# 1        Afghanistan  2013  5.900000              NaN
# 2        Afghanistan  2012  5.454545              NaN
# 3        Afghanistan  2011  5.000000              NaN
# 4        Afghanistan  2010  4.000000              NaN
# ...              ...   ...       ...              ...
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN
#
# [4495 rows x 4 columns]

# %% [markdown]
# # 23

# %%
internet_df = internet_df.rename(columns ={'Country or Area': 'Country', 'Value': 'Internet_Users_Pct'})
internet_df = internet_df.drop(columns = ["Value Footnotes"])

# %% [markdown]
# # 24

# %%
internet_df.shape
# Out:
# (4495, 3)

# %% [markdown]
# The dataset has 4495 rows and 3 columns.

# %%
internet_df["Internet_Users_Pct"] = internet_df["Internet_Users_Pct"].astype(float)
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# # 25

# %%
internet_df.groupby(["Year"]).sum().reset_index()
# Out:
#     Year  Internet_Users_Pct
# 0   1960            0.000000
# 1   1965            0.000000
# 2   1970            0.000000
# 3   1975            0.000000
# 4   1976            0.000000
# 5   1977            0.000000
# 6   1978            0.000000
# 7   1979            0.000000
# 8   1980            0.000000
# 9   1981            0.000000
# 10  1982            0.000000
# 11  1983            0.000000
# 12  1984            0.000000
# 13  1985            0.000000
# 14  1986            0.000000
# 15  1987            0.000000
# 16  1988            0.000000
# 17  1989            0.000000
# 18  1990            5.032933
# 19  1991           10.931876
# 20  1992           19.951850
# 21  1993           30.144702
# 22  1994           60.571026
# 23  1995          131.726726
# 24  1996          253.150223
# 25  1997          454.897179
# 26  1998          750.253424
# 27  1999         1172.587525
# 28  2000         1768.346984
# 29  2001         2198.771961
# 30  2002         2813.872118
# ...

# %% [markdown]
# 1990 is the first year with nonzero internet users percentage reported. The trend of internet usage is increasing from 1990.

# %%
df_for_plot = internet_df.groupby(["Year"]).sum().reset_index()
plt.scatter(df_for_plot["Year"], df_for_plot["Internet_Users_Pct"])
plt.title("Trend In Internet Users by Year")
plt.show()

# %% [markdown]
# # 26

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df, on = ["Country", "Year"])
gdp_and_internet_use = gdp_and_internet_use.dropna()
gdp_and_internet_use
# Out:
#      Continent      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0         Asia  Afghanistan  2014     2102.385234            6.390000
# 1         Asia  Afghanistan  2013     2116.465454            5.900000
# 2         Asia  Afghanistan  2012     2075.491747            5.454545
# 3         Asia  Afghanistan  2011     1904.559799            5.000000
# 4         Asia  Afghanistan  2010     1957.029338            4.000000
# ...        ...          ...   ...             ...                 ...
# 3453    Africa     Zimbabwe  1997     3580.048793            0.033080
# 3454    Africa     Zimbabwe  1996     3520.430146            0.016790
# 3455    Africa     Zimbabwe  1995     3226.413930            0.007684
# 3456    Africa     Zimbabwe  1994     3263.934978            0.001739
# 3457    Africa     Zimbabwe  1990     3324.348171            0.000000
#
# [3458 rows x 5 columns]

# %% [markdown]
# # 27

# %%
gdp_and_internet_use.head()
# Out:
#   Continent      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0      Asia  Afghanistan  2014     2102.385234            6.390000
# 1      Asia  Afghanistan  2013     2116.465454            5.900000
# 2      Asia  Afghanistan  2012     2075.491747            5.454545
# 3      Asia  Afghanistan  2011     1904.559799            5.000000
# 4      Asia  Afghanistan  2010     1957.029338            4.000000

# %%
gdp_and_internet_use.tail()
# Out:
#      Continent   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3453    Africa  Zimbabwe  1997     3580.048793            0.033080
# 3454    Africa  Zimbabwe  1996     3520.430146            0.016790
# 3455    Africa  Zimbabwe  1995     3226.413930            0.007684
# 3456    Africa  Zimbabwe  1994     3263.934978            0.001739
# 3457    Africa  Zimbabwe  1990     3324.348171            0.000000

# %% [markdown]
# # 28

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use[gdp_and_internet_use["Year"] == 2014]
gdp_and_internet_use_2014[gdp_and_internet_use["Internet_Users_Pct"] >= 90].count()
# Out:
# <ipython-input-50-ef771797a3d4>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   gdp_and_internet_use_2014[gdp_and_internet_use["Internet_Users_Pct"] >= 90].count()
# Continent             13
# Country               13
# Year                  13
# GDP_Per_Capita        13
# Internet_Users_Pct    13
# dtype: int64

# %% [markdown]
# 13 countries have internet use greater than or equal to 90%.

# %% [markdown]
# # 29

# %%
gdp_and_internet_use_2014.sort_values("GDP_Per_Capita", ascending = False)
# Out:
#           Continent         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1798         Europe      Luxembourg  2014   108760.916030               94.67
# 2542           Asia           Qatar  2014    95578.416973               91.49
# 2772           Asia       Singapore  2014    87808.663157               82.00
# 372   North America         Bermuda  2014    77361.104881               96.80
# 627   North America  Cayman Islands  2014    66207.447230               74.10
# ...             ...             ...   ...             ...                 ...
# 3098         Africa            Togo  2014     1404.132938                5.70
# 2102         Africa      Mozambique  2014     1217.090210                5.94
# 2256         Africa           Niger  2014     1127.615541                1.95
# 1842         Africa          Malawi  2014     1027.208496                5.83
# 540          Africa         Burundi  2014      886.235777                1.38
#
# [163 rows x 5 columns]

# %%
LQS = ["Luxembourg", "Qatar", "Singapore"]
LQS_gdp_and_internet_use = gdp_and_internet_use[gdp_and_internet_use["Country"].isin(LQS)]
LQS_gdp_and_internet_use
# Out:
#      Continent     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1798    Europe  Luxembourg  2014   108760.916030           94.670000
# 1799    Europe  Luxembourg  2013   106767.275005           93.776500
# 1800    Europe  Luxembourg  2012   105411.464571           91.949924
# 1801    Europe  Luxembourg  2011   108355.582583           90.029859
# 1802    Europe  Luxembourg  2010   108047.346867           90.620000
# ...        ...         ...   ...             ...                 ...
# 2792      Asia   Singapore  1994    46895.053010            1.185204
# 2793      Asia   Singapore  1993    43555.619036            0.763278
# 2794      Asia   Singapore  1992    40077.548794            0.471368
# 2795      Asia   Singapore  1991    38728.403909            0.161504
# 2796      Asia   Singapore  1990    37348.206786            0.000000
#
# [64 rows x 5 columns]

# %%
LQS_gdp_and_internet_use
seaborn_facetplot = sns.FacetGrid(LQS_gdp_and_internet_use, row = "Country")
seaborn_facetplot.map(sns.scatterplot, "Year", "Internet_Users_Pct");

# %% [markdown]
# # 30

# %%
Internet_Users_v_GDP = plt.scatter( gdp_and_internet_use_2014["GDP_Per_Capita"], gdp_and_internet_use_2014["Internet_Users_Pct"])
plt.xlabel("GDP Per Capita"),
plt.ylabel("Percentage Internet Users")
plt.title("Percentage of Internet Use in Population as a function of GDP per Capita")
# Out:
# Text(0.5, 1.0, 'Percentage of Internet Use in Population as a function of GDP per Capita')

# %% [markdown]
# There's a positive correlation between GDP Per Capita and internet use as a percent of the population.

# %% [markdown]
# # 31

# %%
gdp_and_internet_use_2014.corr(method ='pearson')
# Out:
#                     Year  GDP_Per_Capita  Internet_Users_Pct
# Year                 NaN             NaN                 NaN
# GDP_Per_Capita       NaN        1.000000            0.824627
# Internet_Users_Pct   NaN        0.824627            1.000000

# %% [markdown]
# the correlation between GDP_Per_Capita and internet usage is 0.82.  Since correlation has a value between -1 and 1, 0.82 indicates there is a strong positive correlation between GDP Per Capita and internet use

# %% [markdown]
# # 32

# %%
gdp_and_internet_use_2014["log_GDP_Per_Capita"] = np.log10(gdp_and_internet_use_2014["GDP_Per_Capita"])
gdp_and_internet_use_2014
# Out:
# <ipython-input-56-1dd9299dad35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_and_internet_use_2014["log_GDP_Per_Capita"] = np.log10(gdp_and_internet_use_2014["GDP_Per_Capita"])
#           Continent              Country  Year  GDP_Per_Capita  \
# 0              Asia          Afghanistan  2014     2102.385234
# 13           Europe              Albania  2014    11623.866679
# 34           Africa              Algeria  2014    11512.705405
# 56           Africa               Angola  2014     8239.828837
# 76    North America  Antigua and Barbuda  2014    18104.241470
# ...             ...                  ...   ...             ...
# 3348  North America        United States  2014    57273.129074
# ...

# %%
gdp_and_internet_use_2014.corr(method ='pearson')
# Out:
#                     Year  GDP_Per_Capita  Internet_Users_Pct  \
# Year                 NaN             NaN                 NaN
# GDP_Per_Capita       NaN        1.000000            0.824627
# Internet_Users_Pct   NaN        0.824627            1.000000
# log_GDP_Per_Capita   NaN        0.864009            0.903987
#
#                     log_GDP_Per_Capita
# Year                               NaN
# GDP_Per_Capita                0.864009
# Internet_Users_Pct            0.903987
# log_GDP_Per_Capita            1.000000

# %% [markdown]
# the correlation between log_GDP_Per_Capita and internet usage is 0.90. This means the positive correlation is slightly stronger between the log of GDP_Per_Capita and internet usage than it was between GDP Per Capita and the percent of internet users per country.

# %% [markdown]
# # 33

# %%
US_gdp_v_internet_users = gdp_and_internet_use[gdp_and_internet_use["Country"] == "United States"]
US_gdp_v_internet_users.corr(method ='pearson')
# Out:
#                         Year  GDP_Per_Capita  Internet_Users_Pct
# Year                1.000000         0.96344            0.969113
# GDP_Per_Capita      0.963440         1.00000            0.991660
# Internet_Users_Pct  0.969113         0.99166            1.000000

# %% [markdown]
# The correlation between GDP_Per_Capita and percent of internet users is 0.99 meaning the positive correlation between the two is very strong. While the finding seems almost absolute, correlation does not imply causation meaning one cannot infer that wealth leads to internet use.

# %% [markdown]
# # UN Exploration Self Guided Tour Through Military Expenditure

# %%
military_expenditure = pd.read_csv("../data/military_expenditure.csv", nrows= 9300)
military_expenditure = military_expenditure.rename(columns ={'Country or Area': 'Country', 'Value': 'Military_Spending_Pct_GDP'})
military_expenditure = military_expenditure.drop(columns = ["Value Footnotes"]).dropna()
gdp_and_mil_spending_df = pd.merge(gdp_df, military_expenditure, on = ["Country", "Year"])
gdp_and_mil_spending_df
# Out:
#           Continent        Country  Year  GDP_Per_Capita  \
# 0              Asia    Afghanistan  2019     2065.036398
# 1              Asia    Afghanistan  2018     2033.779002
# 2              Asia    Afghanistan  2017     2058.383832
# 3              Asia    Afghanistan  2016     2057.062164
# 4              Asia    Afghanistan  2015     2068.265904
# ...             ...            ...   ...             ...
# 4116  North America  United States  1994    42410.326048
# 4117  North America  United States  1993    41270.867304
# 4118  North America  United States  1992    40698.340183
# 4119  North America  United States  1991    39862.575565
# 4120  North America  United States  1990    40442.601132
#
#       Military_Spending_Pct_GDP
# 0                      1.173908
# 1                      1.006746
# 2                      0.945227
# 3                      0.956772
# 4                      0.994576
# ...                         ...
# 4116                   4.215265
# ...

# %%
gdp_mil_spending_year = gdp_and_mil_spending_df.groupby("Year")
gdp_mil_spending_year.count()
# Out:
#       Continent  Country  GDP_Per_Capita  Military_Spending_Pct_GDP
# Year
# 1990        106      106             106                        106
# 1991        108      108             108                        108
# 1992        118      118             118                        118
# 1993        128      128             128                        128
# 1994        128      128             128                        128
# 1995        132      132             132                        132
# 1996        133      133             133                        133
# 1997        133      133             133                        133
# 1998        131      131             131                        131
# 1999        132      132             132                        132
# 2000        137      137             137                        137
# 2001        138      138             138                        138
# 2002        141      141             141                        141
# ...

# %%
spending_1990 = gdp_and_mil_spending_df[gdp_and_mil_spending_df["Year"] == 1990]
mean_continent = spending_1990.groupby("Continent").mean()
mean_continent = mean_continent.reset_index()
plt.bar(mean_continent["Continent"], mean_continent["Military_Spending_Pct_GDP"])
plt.title("Mean Military Spending % GDP by Continent in 1990");
plt.xticks(rotation = 90);

# %%
mean_continent = spending_1990.groupby("Continent").mean()
mean_continent
# Out:
#                Year  GDP_Per_Capita  Military_Spending_Pct_GDP
# Continent
# Africa         1990     3570.664594                   3.190758
# Asia           1990    15218.535488                   4.792722
# Europe         1990    30876.200280                   2.626866
# North America  1990    12359.551117                   1.615964
# Oceania        1990    17544.594094                   2.026779
# South America  1990     8258.447982                   2.166984

# %%
spending_2019 = gdp_and_mil_spending_df[gdp_and_mil_spending_df["Year"] == 2019]
mean_continent_2019 = (
                        spending_2019
                        .groupby("Continent")
                        .mean()
                        .reset_index()
                        )
plt.bar(mean_continent_2019["Continent"],mean_continent_2019["Military_Spending_Pct_GDP"])
plt.title("Mean Miltary Spending % GDP by Continent in 2019");
plt.xticks(rotation = 90);

# %%
mean_continent_2019 = spending_2019.groupby("Continent").mean()
mean_continent_2019.rename
# Out:
# <bound method DataFrame.rename of                Year  GDP_Per_Capita  Military_Spending_Pct_GDP
# Continent
# Africa         2019     5823.417683                   1.629837
# Asia           2019    23323.355062                   2.791765
# Europe         2019    37939.067887                   1.652248
# North America  2019    19695.863751                   0.953258
# Oceania        2019    27699.183064                   1.342771
# South America  2019    15674.817719                   1.668822>

# %%
spending_1990 = gdp_and_mil_spending_df[gdp_and_mil_spending_df["Year"] == 1990]
spending_1990.rename(columns = {"Year": "1990"})
# Out:
#           Continent         Country  1990  GDP_Per_Capita  \
# 45           Europe         Albania  1990     4842.734635
# 75           Africa         Algeria  1990     8746.352901
# 105          Africa          Angola  1990     5783.429064
# 135   South America       Argentina  1990    14144.762370
# 192         Oceania       Australia  1990    31154.661704
# ...             ...             ...   ...             ...
# 3933         Africa         Tunisia  1990     5432.353529
# 3963           Asia          Turkey  1990    12669.792859
# 3999         Africa          Uganda  1990      907.761598
# 4074         Europe  United Kingdom  1990    30659.973596
# 4120  North America   United States  1990    40442.601132
#
#       Military_Spending_Pct_GDP
# 45                     5.888301
# 75                     1.461071
# 105                   17.463667
# 135                    1.450909
# 192                    2.075906
# ...                         ...
# 3933                   2.012815
# ...

# %%
spending_2019 = gdp_and_mil_spending_df[gdp_and_mil_spending_df["Year"] == 2019]
spending_2019.rename(columns = {"Year": "2019"})
# Out:
#           Continent         Country  2019  GDP_Per_Capita  \
# 0              Asia     Afghanistan  2019     2065.036398
# 16           Europe         Albania  2019    13724.058790
# 46           Africa         Algeria  2019    11510.557088
# 76           Africa          Angola  2019     6670.332297
# 106   South America       Argentina  2019    22063.904372
# ...             ...             ...   ...             ...
# 3970         Africa          Uganda  2019     2187.464881
# 4000         Europe         Ukraine  2019    12810.289455
# 4045         Europe  United Kingdom  2019    46702.978419
# 4075  South America         Uruguay  2019    21561.062055
# 4091  North America   United States  2019    62530.389595
#
#       Military_Spending_Pct_GDP
# 0                      1.173908
# 16                     1.272559
# 46                     6.009523
# 76                     1.644661
# 106                    0.706521
# ...                         ...
# 3970                   2.050106
# ...

# %%
new_spending_df = pd.merge(spending_1990, spending_2019, on = ["Country", "Continent",])
new_spending_df = new_spending_df.rename(columns = {'Year_x': '1990', 'GDP_Pr_Capita_x': 'GDP_Per_Capita_1990', 'Military_Spending_Pct_GDP_x': 
                                                    'Military_Spending_Pct_GDP_1990', 'Year_y': '2019', 'GDP_Per_Capita_y': 'GDP_Per_Capita_2019',
                                                    'Military_Spending_Pct_GDP_y': 'Military_Spending_Pct_GDP_2019'})
new_spending_df
# Out:
#          Continent         Country  1990  GDP_Per_Capita_x  \
# 0           Europe         Albania  1990       4842.734635
# 1           Africa         Algeria  1990       8746.352901
# 2           Africa          Angola  1990       5783.429064
# 3    South America       Argentina  1990      14144.762370
# 4          Oceania       Australia  1990      31154.661704
# ..             ...             ...   ...               ...
# 100         Africa         Tunisia  1990       5432.353529
# 101           Asia          Turkey  1990      12669.792859
# 102         Africa          Uganda  1990        907.761598
# 103         Europe  United Kingdom  1990      30659.973596
# 104  North America   United States  1990      40442.601132
#
#      Military_Spending_Pct_GDP_1990  2019  GDP_Per_Capita_2019  \
# 0                          5.888301  2019         13724.058790
# 1                          1.461071  2019         11510.557088
# 2                         17.463667  2019          6670.332297
# ...

# %%
new_spending_df["Percent_Change_Military_Spending"] = 100 * ((new_spending_df["Military_Spending_Pct_GDP_2019"] - new_spending_df["Military_Spending_Pct_GDP_1990"]) / new_spending_df["Military_Spending_Pct_GDP_1990"])

# %%
new_spending_df.sort_values("Percent_Change_Military_Spending", ascending = False)
# Out:
#         Continent     Country  1990  GDP_Per_Capita_x  \
# 1          Africa     Algeria  1990       8746.352901
# 51  North America     Jamaica  1990       8591.401393
# 41  South America      Guyana  1990       4843.072726
# 36         Africa  The Gambia  1990       2265.238219
# 23  South America    Colombia  1990       8335.515407
# ..            ...         ...   ...               ...
# 32         Africa    Ethiopia  1990        767.013549
# 42  North America       Haiti  1990       3229.618638
# 77  North America      Panama  1990      10728.010764
# 24  North America  Costa Rica  1990       9867.870781
# 44         Europe     Iceland  1990      34182.981632
#
#     Military_Spending_Pct_GDP_1990  2019  GDP_Per_Capita_2019  \
# 1                         1.461071  2019         11510.557088
# 51                        0.840785  2019          9761.498522
# 41                        0.905828  2019         13082.353035
# 36                        0.461266  2019          2222.870122
# ...

# %%
percent_change_NA = new_spending_df[new_spending_df["Continent"] == "North America"].sort_values("Percent_Change_Military_Spending", ascending = False)
percent_change_NA[["Country", "Percent_Change_Military_Spending"]]
# Out:
#                 Country  Percent_Change_Military_Spending
# 51              Jamaica                         90.859114
# 66               Mexico                         19.341056
# 27   Dominican Republic                          8.053871
# 9                Belize                         -0.927748
# 43             Honduras                        -25.975069
# 19               Canada                        -34.636075
# 104       United States                        -39.107941
# 30          El Salvador                        -64.996899
# 40            Guatemala                        -75.779600
# 42                Haiti                        -98.740105
# 77               Panama                       -100.000000
# 24           Costa Rica                               NaN

# %%
plt.scatter(new_spending_df["Continent"], new_spending_df["Percent_Change_Military_Spending"])

# %%
sns.boxplot(new_spending_df["Continent"], new_spending_df["Percent_Change_Military_Spending"])
# Out:
# C:\Users\bng19\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Continent', ylabel='Percent_Change_Military_Spending'>
