# %% [markdown]
# # 3,4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # 5

# %%
gdp_df = pd.read_csv("../data/gdp_per_capita.csv")

# %%
gdp_df
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# ...

# %%
gdp_df.head(10)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN
# 6     Afghanistan  2013  2116.465454              NaN
# 7     Afghanistan  2012  2075.491747              NaN
# 8     Afghanistan  2011  1904.559799              NaN
# 9     Afghanistan  2010  1957.029338              NaN

# %%
gdp_df.tail(5)
# Out:
#      Country or Area                                      Year        Value  \
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 6865              NaN
# 6866              NaN
# 6867              NaN
# 6868              NaN
# 6869              NaN

# %%
gdp_df = pd.read_csv("C:/Users/bng19/Documents/nss_projects/un_exploration-elavender1/data/gdp_per_capita.csv", nrows = 6868)

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2019  2065.036398              NaN
# 1        Afghanistan  2018  2033.779002              NaN
# 2        Afghanistan  2017  2058.383832              NaN
# 3        Afghanistan  2016  2057.062164              NaN
# 4        Afghanistan  2015  2068.265904              NaN
# ...              ...   ...          ...              ...
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN
#
# [6868 rows x 4 columns]

# %% [markdown]
# # 6

# %%
gdp_df = gdp_df.drop("Value Footnotes", axis = 1)

# %%
gdp_df.rename(columns = {"Country or Area": "Country", "Year": "Year", "Value": "GDP_Per_Capita"}, inplace = True)

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %% [markdown]
# # 7

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6868 entries, 0 to 6867
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6868 non-null   object
#  1   Year            6868 non-null   int64
#  2   GDP_Per_Capita  6868 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 134.2+ KB

# %%
gdp_df.shape
# Out:
# (6868, 3)

# %% [markdown]
# # The dataset contains 6868 rows and 3 columns. The column country is an object. The column Year is an integer, and the column GDP_Per_Capita is a float.

# %% [markdown]
# # 8

# %%
gdp_df.sort_values("Year", ascending = False)
# Out:
#                               Country  Year  GDP_Per_Capita
# 0                         Afghanistan  2019     2065.036398
# 6752               West Bank and Gaza  2019     6219.960291
# 2171                          Germany  2019    53810.565452
# 256                         Australia  2019    49609.044033
# 5734                        Sri Lanka  2019    13078.098115
# ...                               ...   ...             ...
# 1753                      El Salvador  1990     5264.664725
# 1783                Equatorial Guinea  1990     1039.985049
# 5943  Sub-Saharan Africa (IDA & IBRD)  1990     2838.374656
# 1840                         Eswatini  1990     5097.842205
# 6867                         Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
gdp_df.groupby("Year").count()
# Out:
#       Country  GDP_Per_Capita
# Year
# 1990      207             207
# 1991      208             208
# 1992      209             209
# 1993      212             212
# 1994      214             214
# 1995      221             221
# 1996      221             221
# 1997      223             223
# 1998      223             223
# 1999      224             224
# 2000      231             231
# 2001      232             232
# 2002      233             233
# 2003      233             233
# 2004      234             234
# 2005      234             234
# 2006      235             235
# 2007      235             235
# 2008      235             235
# 2009      236             236
# 2010      236             236
# 2011      237             237
# 2012      237             237
# 2013      238             238
# 2014      238             238
# 2015      238             238
# 2016      238             238
# 2017      238             238
# 2018      237             237
# 2019      231             231

# %% [markdown]
# #8 The data ranges from the years 1990 to 2019. There is a trend of increasing observations per year.  In 1990, the dataset only contained 207 observations.  In 2019, it contained 231.

# %% [markdown]
# # 9

# %%
country_sort = gdp_df.groupby("Country").count()

# %%
country_sort
# Out:
#                      Year  GDP_Per_Capita
# Country
# Afghanistan            18              18
# Albania                30              30
# Algeria                30              30
# Angola                 30              30
# Antigua and Barbuda    30              30
# ...                   ...             ...
# Vietnam                30              30
# West Bank and Gaza     26              26
# World                  30              30
# Zambia                 30              30
# Zimbabwe               30              30
#
# [238 rows x 2 columns]

# %%
country_sort.sort_values("Year", ascending = True)
# Out:
#                            Year  GDP_Per_Capita
# Country
# Djibouti                      7               7
# Turks and Caicos Islands      9               9
# Sint Maarten (Dutch part)    10              10
# Cayman Islands               13              13
# Nauru                        16              16
# ...                         ...             ...
# Honduras                     30              30
# Hong Kong SAR, China         30              30
# IBRD only                    30              30
# Greece                       30              30
# Zimbabwe                     30              30
#
# [238 rows x 2 columns]

# %% [markdown]
# #9 238 countries are represented in the dataset.  Djibouti, Turks and Caicos Islands, Sint Maarten (Dutch part) Cayman Islands and Nauru are least represented. Without knowing the methods in which the data was collected, one could only speculate why some countries are less represented than others.

# %% [markdown]
# # 10

# %%
gdp_2014 = gdp_df[gdp_df["Year"] == 2014]

# %%
gdp_2014
# Out:
#                   Country  Year  GDP_Per_Capita
# 5             Afghanistan  2014     2102.385234
# 23                Albania  2014    11623.866679
# 53                Algeria  2014    11512.705405
# 83                 Angola  2014     8239.828837
# 113   Antigua and Barbuda  2014    18104.241470
# ...                   ...   ...             ...
# 6727              Vietnam  2014     6098.489609
# 6757   West Bank and Gaza  2014     5967.073437
# 6783                World  2014    15189.648507
# 6813               Zambia  2014     3450.046561
# 6843             Zimbabwe  2014     2955.240287
#
# [238 rows x 3 columns]

# %% [markdown]
# # 11

# %%
gdp_2014.describe()
# Out:
#          Year  GDP_Per_Capita
# count   238.0      238.000000
# mean   2014.0    19766.710348
# std       0.0    20983.869623
# min    2014.0      822.610458
# 25%    2014.0     4753.110934
# 50%    2014.0    12209.385755
# 75%    2014.0    26803.610474
# max    2014.0   156514.133850

# %% [markdown]
# # 12

# %%
gdp_per_capita_2014 = gdp_2014[["GDP_Per_Capita"]]

# %%
plt.hist(gdp_per_capita_2014, bins = 15)
# Out:
# (array([105.,  57.,  25.,  17.,  17.,   9.,   3.,   1.,   1.,   1.,   1.,
#           0.,   0.,   0.,   1.]),
#  array([   822.61045782,  11202.04535061,  21581.48024341,  31960.91513621,
#          42340.35002901,  52719.78492181,  63099.2198146 ,  73478.6547074 ,
#          83858.0896002 ,  94237.524493  , 104616.95938579, 114996.39427859,
#         125375.82917139, 135755.26406419, 146134.69895699, 156514.13384978]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# #12 the distribution is skewed to the left with a few outliers on the far right.

# %% [markdown]
# # 13

# %%
gdp_2014.sort_values("GDP_Per_Capita", ascending = True)
# Out:
#                        Country  Year  GDP_Per_Capita
# 1047  Central African Republic  2014      822.610458
# 827                    Burundi  2014      886.235777
# 3781                    Malawi  2014     1027.208496
# 1422           Dem. Rep. Congo  2014     1029.790785
# 4528                     Niger  2014     1127.615541
# ...                        ...   ...             ...
# 561                    Bermuda  2014    77361.104881
# 5464                 Singapore  2014    87808.663157
# 5138                     Qatar  2014    95578.416973
# 3691                Luxembourg  2014   108760.916030
# 3721          Macao SAR, China  2014   156514.133850
#
# [238 rows x 3 columns]

# %%
gdp_2014.sort_values("GDP_Per_Capita", ascending = False)
# Out:
#                        Country  Year  GDP_Per_Capita
# 3721          Macao SAR, China  2014   156514.133850
# 3691                Luxembourg  2014   108760.916030
# 5138                     Qatar  2014    95578.416973
# 5464                 Singapore  2014    87808.663157
# 561                    Bermuda  2014    77361.104881
# ...                        ...   ...             ...
# 4528                     Niger  2014     1127.615541
# 1422           Dem. Rep. Congo  2014     1029.790785
# 3781                    Malawi  2014     1027.208496
# 827                    Burundi  2014      886.235777
# 1047  Central African Republic  2014      822.610458
#
# [238 rows x 3 columns]

# %% [markdown]
# #13 1) Macao SAR, China, 2) Luxembourg, 3) Qatar, 4) Singapore, 5) Bermuda are the top 5 countries.
#
# 1) Central African Republic, 2) Burundi, 3) Malawi, 4) Dem. Rep. Congo 5) Niger are the bottom 5 countries

# %% [markdown]
# # 14

# %%
gdp_pivoted = gdp_df.pivot_table(values = "GDP_Per_Capita", index = "Country", columns = "Year")

# %%
gdp_pivoted.columns
# Out:
# Int64Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
#            dtype='int64', name='Year')

# %%
gdp_pivoted = gdp_pivoted.dropna()

# %%
gdp_pivoted
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# Arab World            9694.667544   9651.626577   9933.531454   9927.649928
# ...                           ...           ...           ...           ...
# Vanuatu               2888.309393   2897.327707   2886.920558   2824.882319
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %% [markdown]
# # 15

# %%
percent_change = 100 * (gdp_df["Year"] = 2017 - gdp_df["Year"] = 1990 / gdp_df["Year"] = 1990)
# Out:
#   File "<ipython-input-143-2eddbf2ce337>", line 1
#     percent_change = 100 * (gdp_df["Year"] = 2017 - gdp_df["Year"] = 1990 / gdp_df["Year"] = 1990)
#                                            ^
# SyntaxError: invalid syntax

# %%
gdp_1990 = gdp_df["1990"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1990'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-8afd23f5b7df> in <module>
# ----> 1 gdp_1990 = gdp_df["1990"]
#
# ...

# %%
gdp_2017 = gdp_df["2017"]

# %%
percent_change = 100 * (gdp_2017 - gdp_1990 / gdp_1990)

# %%
gdp_df["Percent_Change"] = percent_change

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita  Percent_Change
# 0     Afghanistan  2017     2065.036398        201600.0
# 1     Afghanistan  2017     2033.779002        201600.0
# 2     Afghanistan  2017     2058.383832        201600.0
# 3     Afghanistan  2017     2057.062164        201600.0
# 4     Afghanistan  2017     2068.265904        201600.0
# ...           ...   ...             ...             ...
# 6863     Zimbabwe  2017     3263.934978        201600.0
# 6864     Zimbabwe  2017     3033.504852        201600.0
# 6865     Zimbabwe  2017     3054.889178        201600.0
# 6866     Zimbabwe  2017     3426.598094        201600.0
# 6867     Zimbabwe  2017     3324.348171        201600.0
#
# [6868 rows x 4 columns]
